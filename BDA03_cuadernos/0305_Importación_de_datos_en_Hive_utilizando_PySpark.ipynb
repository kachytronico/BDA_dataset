# %% [markdown]
# # Importación de Datos en Hive utilizando PySparlk

# %% [markdown]
# Importación de datos

# %%
# !wget -q https://dlcdn.apache.org/spark/spark-4.1.1/spark-4.1.1-bin-hadoop3.tgz
# !tar xf spark-4.1.1-bin-hadoop3.tgz
# !pip install -q findspark
# !pip install pyspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-4.1.1-bin-hadoop3"
import findspark
findspark.init()
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: py4j==0.10.9.9 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %% [markdown]
# Leer un fichero con spark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Learning_Spark") \
    .getOrCreate()

sc = spark.sparkContext

# %% [markdown]
# Leer multitud de ficheros con Spark

# %%
input = sc.textFile("spark-4.1.1-bin-hadoop3/*.md")
input
# Out:
# spark-4.1.1-bin-hadoop3/*.md MapPartitionsRDD[1] at textFile at NativeMethodAccessorImpl.java:0

# %% [markdown]
# Leer JSON

# %%
# !wget https://raw.githubusercontent.com/hassanarteaga/CosmosDBJSONExamples/master/Example1.json
# Out:
# --2026-01-15 11:21:54--  https://raw.githubusercontent.com/hassanarteaga/CosmosDBJSONExamples/master/Example1.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2427 (2.4K) [text/plain]
# Saving to: ‘Example1.json’
#
# Example1.json       100%[===================>]   2.37K  --.-KB/s    in 0s
#
# 2026-01-15 11:21:54 (31.3 MB/s) - ‘Example1.json’ saved [2427/2427]

# %%
jsonDF = spark.read.option("multiline","true").json('Example1.json')
jsonDF.show()
# Out:
# +--------------------+--------+-------------+--------------------+--------------------+---------+--------------------+
# |          activities|end_date|event_country|          event_name|                  id|init_date|             speaker|
# +--------------------+--------+-------------+--------------------+--------------------+---------+--------------------+
# |[{30, Using Cosmo...|20180615|       MEXICO|       CosmosDB Conf|6e3bed84-bd7e-4c6...| 20180613|Hassan Arteaga Ro...|
# |[{30, In Vue we t...|20180503|          USA|    Vue.js Conf 2018|204831ad-d190-49f...| 20180501|Hassan Arteaga Ro...|
# |[{30, CosmosDB in...|20180625|      GERMANY|           IoT Space|a4b0e429-3455-439...| 20180621|Lourdes M. Guada ...|
# |[{30, CosmosDB Pa...|20180615|       MEXICO|       CosmosDB Conf|70fc0d83-768e-42b...| 20180613|Lourdes M. Guada ...|
# |[{30, CosmosDB a ...|20180412|       MEXICO|Cloud Conference ...|f3c965b4-39e8-4e5...| 20180411|Zamir Alejandro A...|
# +--------------------+--------+-------------+--------------------+--------------------+---------+--------------------+

# %%
jsonDF.printSchema()
# Out:
# root
#  |-- activities: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- duration: long (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |-- end_date: long (nullable = true)
#  |-- event_country: string (nullable = true)
#  |-- event_name: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- init_date: long (nullable = true)
#  |-- speaker: string (nullable = true)

# %% [markdown]
# # Gestionando ficheros de texto
#
# Utilizar USDA_activity_dataset_csv
#
# https://github.com/euwern/human-activity-dataset

# %% [markdown]
# **Carga de Datos en Colab**

# %%
# !wget https://raw.githubusercontent.com/curso-iabd-uclm/hadoop/main/pig/casualties/casualties_rates.csv
# Out:
# --2026-01-15 11:22:10--  https://raw.githubusercontent.com/curso-iabd-uclm/hadoop/main/pig/casualties/casualties_rates.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2523392 (2.4M) [text/plain]
# Saving to: ‘casualties_rates.csv’
#
# casualties_rates.cs 100%[===================>]   2.41M  --.-KB/s    in 0.04s
#
# 2026-01-15 11:22:11 (54.4 MB/s) - ‘casualties_rates.csv’ saved [2523392/2523392]

# %% [markdown]
# **Leer el CSV en un Dataframe filtrarlo y salvarlo**

# %%
data = spark.read.csv('casualties_rates.csv',sep = ";", inferSchema=True, header=True)

# %% [markdown]
# Filtrar por diferentes columnas

# %%
dataF=data.select("Country","Year","casualties_no","casualties100k_pop")

# %% [markdown]
# Guardar solo los datos filtrados

# %%
dataF.write.csv("casualties_summary.csv")

# %% [markdown]
# Vamos a leer este nuevo archivo en un RDD

# %%
rddL=sc.textFile("casualties_summary.csv")
rddL.collect()
# Out:
# ['Albania,1987,21,6.71',
#  'Albania,1987,16,5.19',
#  'Albania,1987,14,4.83',
#  'Albania,1987,1,4.59',
#  'Albania,1987,9,3.28',
#  'Albania,1987,1,2.81',
#  'Albania,1987,6,2.15',
#  'Albania,1987,4,1.56',
#  'Albania,1987,1,0.73',
#  'Albania,1987,0,0.0',
#  'Albania,1987,0,0.0',
#  'Albania,1987,0,0.0',
#  'Albania,1988,2,5.49',
#  'Albania,1988,17,5.33',
#  'Albania,1988,1,4.48',
#  'Albania,1988,14,4.46',
#  'Albania,1988,4,2.85',
#  'Albania,1988,8,2.71',
#  'Albania,1988,3,2.03',
#  'Albania,1988,5,1.91',
#  'Albania,1988,5,1.79',
#  'Albania,1988,4,1.41',
#  'Albania,1988,0,0.0',
#  'Albania,1988,0,0.0',
#  'Albania,1989,2,8.89',
#  'Albania,1989,18,6.35',
#  'Albania,1989,15,4.71',
#  'Albania,1989,6,4.22',
#  'Albania,1989,12,3.71',
#  'Albania,1989,7,2.43',
#  'Albania,1989,5,1.67',
#  'Albania,1989,2,0.75',
#  'Albania,1989,1,0.67',
#  'Albania,1989,0,0.0',
#  'Albania,1989,0,0.0',
#  'Albania,1989,0,0.0',
#  'Albania,1992,12,3.49',
#  'Albania,1992,9,3.41',
#  'Albania,1992,5,3.13',
#  'Albania,1992,7,2.85',
#  'Albania,1992,7,2.39',
#  'Albania,1992,4,1.5',
#  'Albania,1992,2,0.62',
#  'Albania,1992,1,0.61',
#  'Albania,1992,0,0.0',
#  'Albania,1992,0,0.0',
#  'Albania,1992,0,0.0',
#  'Albania,1992,0,0.0',
#  'Albania,1993,18,7.4',
#  'Albania,1993,7,4.24',
#  'Albania,1993,1,4.13',
#  'Albania,1993,9,3.91',
#  'Albania,1993,10,3.51',
#  'Albania,1993,10,2.85',
#  'Albania,1993,7,2.67',
#  'Albania,1993,7,2.11',
#  'Albania,1993,2,1.18',
#  'Albania,1993,1,0.29',
#  'Albania,1993,1,0.27',
#  'Albania,1993,0,0.0',
#  'Albania,1994,2,8.13',
#  'Albania,1994,11,6.42',
#  'Albania,1994,2,5.01',
#  'Albania,1994,6,2.59',
#  'Albania,1994,9,2.48',
#  'Albania,1994,6,2.48',
#  'Albania,1994,6,2.12',
#  'Albania,1994,4,1.53',
#  'Albania,1994,2,0.58',
#  'Albania,1994,1,0.57',
#  'Albania,1994,1,0.27',
#  'Albania,1994,0,0.0',
#  'Albania,1995,13,5.58',
#  'Albania,1995,9,5.06',
#  'Albania,1995,2,4.9',
#  'Albania,1995,13,4.59',
#  'Albania,1995,11,4.56',
#  'Albania,1995,1,3.98',
#  'Albania,1995,14,3.72',
#  'Albania,1995,7,2.65',
#  'Albania,1995,8,2.24',
#  'Albania,1995,6,1.59',
#  'Albania,1995,2,1.11',
#  'Albania,1995,2,0.57',
#  'Albania,1996,2,7.87',
#  'Albania,1996,17,6.98',
#  'Albania,1996,14,5.95',
#  'Albania,1996,16,5.56',
#  'Albania,1996,2,4.85',
#  'Albania,1996,10,3.73',
#  'Albania,1996,12,3.16',
#  'Albania,1996,9,2.49',
#  'Albania,1996,3,1.67',
#  'Albania,1996,1,0.55',
#  'Albania,1996,2,0.53',
#  'Albania,1996,1,0.28',
#  'Albania,1997,36,15.25',
#  'Albania,1997,33,13.5',
#  'Albania,1997,3,11.81',
#  'Albania,1997,30,7.88',
#  'Albania,1997,21,7.14',
#  'Albania,1997,12,6.66',
#  'Albania,1997,16,5.84',
#  'Albania,1997,2,4.75',
#  'Albania,1997,7,1.89',
#  'Albania,1997,6,1.66',
#  'Albania,1997,4,1.05',
#  'Albania,1997,0,0.0',
#  'Albania,1998,3,11.63',
#  'Albania,1998,27,10.85',
#  'Albania,1998,32,10.83',
#  'Albania,1998,26,10.82',
#  'Albania,1998,29,7.47',
#  'Albania,1998,9,4.9',
#  'Albania,1998,10,3.63',
#  'Albania,1998,6,3.19',
#  'Albania,1998,9,2.42',
#  'Albania,1998,2,0.51',
#  'Albania,1998,1,0.27',
#  'Albania,1998,0,0.0',
#  'Albania,1999,3,11.58',
#  'Albania,1999,24,9.58',
#  'Albania,1999,4,9.43',
#  'Albania,1999,31,7.93',
#  'Albania,1999,19,7.84',
#  'Albania,1999,14,7.56',
#  'Albania,1999,19,6.4',
#  'Albania,1999,13,4.7',
#  'Albania,1999,6,3.18',
#  'Albania,1999,5,1.34',
#  'Albania,1999,1,0.27',
#  'Albania,1999,0,0.0',
#  'Albania,2000,17,7.33',
#  'Albania,2000,10,5.64',
#  'Albania,2000,2,5.29',
#  'Albania,2000,1,4.02',
#  'Albania,2000,6,2.27',
#  'Albania,2000,5,2.08',
#  'Albania,2000,5,1.51',
#  'Albania,2000,3,1.22',
#  'Albania,2000,4,1.07',
#  'Albania,2000,1,0.27',
#  'Albania,2000,0,0.0',
#  'Albania,2000,0,0.0',
#  'Albania,2001,22,10.65',
#  'Albania,2001,34,8.98',
#  'Albania,2001,11,5.59',
#  'Albania,2001,2,4.23',
#  'Albania,2001,10,3.91',
#  'Albania,2001,9,3.32',
#  'Albania,2001,12,3.24',
#  'Albania,2001,1,3.22',
#  'Albania,2001,6,3.16',
#  'Albania,2001,6,1.87',
#  'Albania,2001,4,1.8',
#  'Albania,2001,2,0.65',
#  'Albania,2002,4,12.9',
#  'Albania,2002,23,11.15',
#  'Albania,2002,35,9.16',
#  'Albania,2002,13,6.56',
#  'Albania,2002,15,5.7',
#  'Albania,2002,14,5.07',
#  'Albania,2002,15,4.0',
#  'Albania,2002,7,3.13',
#  'Albania,2002,1,2.11',
#  'Albania,2002,4,2.09',
#  'Albania,2002,1,0.33',
#  'Albania,2002,1,0.31',
#  'Albania,2003,6,12.22',
#  'Albania,2003,16,7.94',
#  'Albania,2003,28,7.25',
#  'Albania,2003,15,5.49',
#  'Albania,2003,14,4.93',
#  'Albania,2003,9,4.6',
#  'Albania,2003,9,4.38',
#  'Albania,2003,9,4.04',
#  'Albania,2003,13,3.41',
#  'Albania,2003,1,3.06',
#  'Albania,2003,4,1.28',
#  'Albania,2003,0,0.0',
#  'Albania,2004,4,11.26',
#  'Albania,2004,39,9.95',
#  'Albania,2004,16,7.85',
#  'Albania,2004,20,6.84',
#  'Albania,2004,19,6.63',
#  'Albania,2004,3,5.89',
#  'Albania,2004,11,4.95',
#  'Albania,2004,10,4.83',
#  'Albania,2004,17,4.34',
#  'Albania,2004,3,1.47',
#  'Albania,2004,3,1.05',
#  'Albania,2004,1,0.33',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2005,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2006,0,0.0',
#  'Albania,2007,8,18.88',
#  'Albania,2007,29,7.66',
#  'Albania,2007,14,6.25',
#  'Albania,2007,3,5.23',
#  'Albania,2007,9,5.22',
#  'Albania,2007,13,4.63',
#  'Albania,2007,13,4.51',
#  'Albania,2007,8,4.36',
#  'Albania,2007,9,4.07',
#  'Albania,2007,14,3.57',
#  'Albania,2007,4,1.47',
#  'Albania,2007,0,0.0',
#  'Albania,2008,21,12.15',
#  'Albania,2008,37,9.81',
#  'Albania,2008,21,9.18',
#  'Albania,2008,5,8.42',
#  'Albania,2008,20,7.24',
#  'Albania,2008,9,4.93',
#  'Albania,2008,19,4.82',
#  'Albania,2008,2,4.49',
#  'Albania,2008,11,3.84',
#  'Albania,2008,7,3.09',
#  'Albania,2008,7,2.67',
#  'Albania,2008,1,0.41',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2009,0,0.0',
#  'Albania,2010,20,8.27',
#  'Albania,2010,20,5.38',
#  'Albania,2010,9,5.01',
#  'Albania,2010,2,3.94',
#  'Albania,2010,10,3.58',
#  'Albania,2010,6,3.27',
#  'Albania,2010,2,3.1',
#  'Albania,2010,12,3.04',
#  'Albania,2010,7,2.9',
#  'Albania,2010,6,2.28',
#  'Albania,2010,2,0.89',
#  'Albania,2010,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1985,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1986,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1987,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1988,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1989,0,0.0',
#  'Antigua and Barbuda,1990,1,17.24',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1990,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1991,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1992,0,0.0',
#  'Antigua and Barbuda,1993,1,15.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1993,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1994,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1995,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1998,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,1999,0,0.0',
#  'Antigua and Barbuda,2000,1,30.0',
#  'Antigua and Barbuda,2000,1,9.97',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2000,0,0.0',
#  'Antigua and Barbuda,2001,2,19.45',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2001,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2002,0,0.0',
#  'Antigua and Barbuda,2003,1,27.82',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2003,0,0.0',
#  'Antigua and Barbuda,2004,1,27.29',
#  'Antigua and Barbuda,2004,1,8.77',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2004,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2005,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2006,0,0.0',
#  'Antigua and Barbuda,2007,1,7.98',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2007,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2008,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2009,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2012,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2013,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2014,0,0.0',
#  'Antigua and Barbuda,2015,1,15.62',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Antigua and Barbuda,2015,0,0.0',
#  'Argentina,1985,202,55.65',
#  'Argentina,1985,485,24.29',
#  'Argentina,1985,414,12.37',
#  'Argentina,1985,210,9.11',
#  'Argentina,1985,177,7.92',
#  'Argentina,1985,41,7.64',
#  'Argentina,1985,156,6.46',
#  'Argentina,1985,142,4.23',
#  'Argentina,1985,65,2.97',
#  'Argentina,1985,69,2.93',
#  'Argentina,1985,16,0.53',
#  'Argentina,1985,11,0.37',
#  'Argentina,1986,230,63.01',
#  'Argentina,1986,530,26.39',
#  'Argentina,1986,478,14.2',
#  'Argentina,1986,209,9.3',
#  'Argentina,1986,48,8.89',
#  'Argentina,1986,201,8.67',
#  'Argentina,1986,186,7.66',
#  'Argentina,1986,188,5.57',
#  'Argentina,1986,96,4.37',
#  'Argentina,1986,101,4.27',
#  'Argentina,1986,10,0.33',
#  'Argentina,1986,7,0.24',
#  'Argentina,1987,200,54.08',
#  'Argentina,1987,532,26.15',
#  'Argentina,1987,482,14.14',
#  'Argentina,1987,57,10.42',
#  'Argentina,1987,224,9.54',
#  'Argentina,1987,192,8.44',
#  'Argentina,1987,179,7.27',
#  'Argentina,1987,209,6.11',
#  'Argentina,1987,89,4.0',
#  'Argentina,1987,93,3.88',
#  'Argentina,1987,15,0.48',
#  'Argentina,1987,14,0.47',
#  'Argentina,1988,216,55.1',
#  'Argentina,1988,550,26.46',
#  'Argentina,1988,477,13.62',
#  'Argentina,1988,61,10.13',
#  'Argentina,1988,233,9.66',
#  'Argentina,1988,215,9.45',
#  'Argentina,1988,211,8.36',
#  'Argentina,1988,198,5.64',
#  'Argentina,1988,101,4.11',
#  'Argentina,1988,61,2.74',
#  'Argentina,1988,20,0.62',
#  'Argentina,1988,11,0.35',
#  'Argentina,1989,208,52.0',
#  'Argentina,1989,548,26.03',
#  'Argentina,1989,462,12.97',
#  'Argentina,1989,65,10.45',
#  'Argentina,1989,219,9.58',
#  'Argentina,1989,201,8.22',
#  'Argentina,1989,186,7.22',
#  'Argentina,1989,166,4.66',
#  'Argentina,1989,83,3.71',
#  'Argentina,1989,80,3.19',
#  'Argentina,1989,18,0.55',
#  'Argentina,1989,11,0.35',
#  'Argentina,1990,226,54.97',
#  'Argentina,1990,502,23.59',
#  'Argentina,1990,439,12.13',
#  'Argentina,1990,61,9.49',
#  'Argentina,1990,182,7.92',
#  'Argentina,1990,190,7.67',
#  'Argentina,1990,174,6.6',
#  'Argentina,1990,163,4.5',
#  'Argentina,1990,91,3.54',
#  'Argentina,1990,76,3.38',
#  'Argentina,1990,22,0.67',
#  'Argentina,1990,14,0.44',
#  'Argentina,1991,184,46.46',
#  'Argentina,1991,449,21.08',
#  'Argentina,1991,398,11.12',
#  'Argentina,1991,214,9.4',
#  'Argentina,1991,50,7.6',
#  'Argentina,1991,169,6.74',
#  'Argentina,1991,179,6.54',
#  'Argentina,1991,133,3.6',
#  'Argentina,1991,77,3.33',
#  'Argentina,1991,61,2.27',
#  'Argentina,1991,28,0.83',
#  'Argentina,1991,9,0.27',
#  'Argentina,1992,194,47.91',
#  'Argentina,1992,500,23.25',
#  'Argentina,1992,488,13.49',
#  'Argentina,1992,227,9.84',
#  'Argentina,1992,249,8.79',
#  'Argentina,1992,46,6.78',
#  'Argentina,1992,147,5.79',
#  'Argentina,1992,140,3.73',
#  'Argentina,1992,79,3.39',
#  'Argentina,1992,79,2.84',
#  'Argentina,1992,22,0.65',
#  'Argentina,1992,13,0.4',
#  'Argentina,1993,229,55.37',
#  'Argentina,1993,520,23.95',
#  'Argentina,1993,495,13.48',
#  'Argentina,1993,233,9.97',
#  'Argentina,1993,58,8.3',
#  'Argentina,1993,235,8.01',
#  'Argentina,1993,126,4.91',
#  'Argentina,1993,144,3.77',
#  'Argentina,1993,76,3.24',
#  'Argentina,1993,73,2.54',
#  'Argentina,1993,25,0.74',
#  'Argentina,1993,16,0.49',
#  'Argentina,1994,192,45.38',
#  'Argentina,1994,509,23.22',
#  'Argentina,1994,527,14.13',
#  'Argentina,1994,226,9.54',
#  'Argentina,1994,250,8.26',
#  'Argentina,1994,135,5.2',
#  'Argentina,1994,34,4.72',
#  'Argentina,1994,160,4.12',
#  'Argentina,1994,98,3.3',
#  'Argentina,1994,72,3.04',
#  'Argentina,1994,27,0.8',
#  'Argentina,1994,11,0.34',
#  'Argentina,1995,190,43.8',
#  'Argentina,1995,515,23.26',
#  'Argentina,1995,485,12.8',
#  'Argentina,1995,218,9.06',
#  'Argentina,1995,277,8.9',
#  'Argentina,1995,49,6.6',
#  'Argentina,1995,134,5.1',
#  'Argentina,1995,139,3.52',
#  'Argentina,1995,101,3.31',
#  'Argentina,1995,62,2.59',
#  'Argentina,1995,19,0.58',
#  'Argentina,1995,15,0.45',
#  'Argentina,1996,189,42.4',
#  'Argentina,1996,464,20.75',
#  'Argentina,1996,524,13.62',
#  'Argentina,1996,226,9.25',
#  'Argentina,1996,280,8.79',
#  'Argentina,1996,59,7.7',
#  'Argentina,1996,131,4.94',
#  'Argentina,1996,176,4.38',
#  'Argentina,1996,105,3.36',
#  'Argentina,1996,52,2.14',
#  'Argentina,1996,14,0.42',
#  'Argentina,1996,9,0.28',
#  'Argentina,1997,195,39.78',
#  'Argentina,1997,457,20.29',
#  'Argentina,1997,501,12.73',
#  'Argentina,1997,213,8.66',
#  'Argentina,1997,260,8.13',
#  'Argentina,1997,47,5.5',
#  'Argentina,1997,131,4.91',
#  'Argentina,1997,165,4.04',
#  'Argentina,1997,113,3.57',
#  'Argentina,1997,72,2.91',
#  'Argentina,1997,19,0.55',
#  'Argentina,1997,11,0.33',
#  'Argentina,1998,201,39.87',
#  'Argentina,1998,518,22.77',
#  'Argentina,1998,508,12.73',
#  'Argentina,1998,327,10.08',
#  'Argentina,1998,251,10.05',
#  'Argentina,1998,53,6.0',
#  'Argentina,1998,140,5.19',
#  'Argentina,1998,114,3.56',
#  'Argentina,1998,147,3.55',
#  'Argentina,1998,52,2.07',
#  'Argentina,1998,20,0.6',
#  'Argentina,1998,16,0.46',
#  'Argentina,1999,204,39.55',
#  'Argentina,1999,540,23.46',
#  'Argentina,1999,545,13.47',
#  'Argentina,1999,355,10.82',
#  'Argentina,1999,265,10.42',
#  'Argentina,1999,137,5.02',
#  'Argentina,1999,44,4.82',
#  'Argentina,1999,141,3.36',
#  'Argentina,1999,101,3.13',
#  'Argentina,1999,50,1.95',
#  'Argentina,1999,21,0.6',
#  'Argentina,1999,20,0.59',
#  'Argentina,2000,232,44.18',
#  'Argentina,2000,602,25.8',
#  'Argentina,2000,578,14.11',
#  'Argentina,2000,463,14.0',
#  'Argentina,2000,331,12.72',
#  'Argentina,2000,133,4.82',
#  'Argentina,2000,43,4.56',
#  'Argentina,2000,174,4.09',
#  'Argentina,2000,116,3.57',
#  'Argentina,2000,63,2.41',
#  'Argentina,2000,21,0.62',
#  'Argentina,2000,18,0.51',
#  'Argentina,2001,250,45.66',
#  'Argentina,2001,659,27.94',
#  'Argentina,2001,518,15.58',
#  'Argentina,2001,625,15.08',
#  'Argentina,2001,375,14.02',
#  'Argentina,2001,57,5.83',
#  'Argentina,2001,166,5.09',
#  'Argentina,2001,137,4.91',
#  'Argentina,2001,210,4.88',
#  'Argentina,2001,82,3.05',
#  'Argentina,2001,29,0.82',
#  'Argentina,2001,24,0.7',
#  'Argentina,2002,234,41.31',
#  'Argentina,2002,615,25.76',
#  'Argentina,2002,542,16.27',
#  'Argentina,2002,412,14.94',
#  'Argentina,2002,619,14.77',
#  'Argentina,2002,179,6.35',
#  'Argentina,2002,58,5.73',
#  'Argentina,2002,158,4.84',
#  'Argentina,2002,194,4.45',
#  'Argentina,2002,91,3.28',
#  'Argentina,2002,37,1.05',
#  'Argentina,2002,23,0.67',
#  'Argentina,2003,272,46.75',
#  'Argentina,2003,577,23.83',
#  'Argentina,2003,638,19.15',
#  'Argentina,2003,456,16.02',
#  'Argentina,2003,625,14.75',
#  'Argentina,2003,68,6.51',
#  'Argentina,2003,179,5.49',
#  'Argentina,2003,147,5.15',
#  'Argentina,2003,196,4.45',
#  'Argentina,2003,69,2.41',
#  'Argentina,2003,37,1.05',
#  'Argentina,2003,25,0.73',
#  'Argentina,2004,227,38.25',
#  'Argentina,2004,500,20.33',
#  'Argentina,2004,653,19.59',
#  'Argentina,2004,445,15.19',
#  'Argentina,2004,599,13.98',
#  'Argentina,2004,159,4.88',
#  'Argentina,2004,136,4.7',
#  'Argentina,2004,50,4.66',
#  'Argentina,2004,185,4.16',
#  'Argentina,2004,99,3.37',
#  'Argentina,2004,43,1.22',
#  'Argentina,2004,25,0.73',
#  'Argentina,2005,225,37.43',
#  'Argentina,2005,489,19.52',
#  'Argentina,2005,638,19.08',
#  'Argentina,2005,451,15.01',
#  'Argentina,2005,539,12.43',
#  'Argentina,2005,161,5.47',
#  'Argentina,2005,59,5.36',
#  'Argentina,2005,148,4.54',
#  'Argentina,2005,171,3.8',
#  'Argentina,2005,104,3.45',
#  'Argentina,2005,52,1.47',
#  'Argentina,2005,21,0.62',
#  'Argentina,2006,246,39.68',
#  'Argentina,2006,656,19.54',
#  'Argentina,2006,487,19.17',
#  'Argentina,2006,483,15.74',
#  'Argentina,2006,585,13.34',
#  'Argentina,2006,175,5.35',
#  'Argentina,2006,115,3.85',
#  'Argentina,2006,160,3.52',
#  'Argentina,2006,105,3.42',
#  'Argentina,2006,31,2.74',
#  'Argentina,2006,39,1.11',
#  'Argentina,2006,26,0.76',
#  'Argentina,2007,225,35.43',
#  'Argentina,2007,577,17.07',
#  'Argentina,2007,438,16.96',
#  'Argentina,2007,490,15.68',
#  'Argentina,2007,571,12.87',
#  'Argentina,2007,146,4.43',
#  'Argentina,2007,126,4.04',
#  'Argentina,2007,108,3.56',
#  'Argentina,2007,155,3.37',
#  'Argentina,2007,31,2.67',
#  'Argentina,2007,45,1.27',
#  'Argentina,2007,34,1.0',
#  'Argentina,2008,208,32.19',
#  'Argentina,2008,625,18.33',
#  'Argentina,2008,463,17.6',
#  'Argentina,2008,531,16.74',
#  'Argentina,2008,582,12.94',
#  'Argentina,2008,180,5.42',
#  'Argentina,2008,173,3.71',
#  'Argentina,2008,108,3.5',
#  'Argentina,2008,36,3.03',
#  'Argentina,2008,94,2.97',
#  'Argentina,2008,39,1.1',
#  'Argentina,2008,20,0.58',
#  'Argentina,2009,177,27.09',
#  'Argentina,2009,609,17.72',
#  'Argentina,2009,434,16.17',
#  'Argentina,2009,504,15.7',
#  'Argentina,2009,542,11.87',
#  'Argentina,2009,164,4.91',
#  'Argentina,2009,112,3.56',
#  'Argentina,2009,105,3.29',
#  'Argentina,2009,150,3.17',
#  'Argentina,2009,25,2.06',
#  'Argentina,2009,34,0.96',
#  'Argentina,2009,28,0.82',
#  'Argentina,2010,206,31.35',
#  'Argentina,2010,683,19.77',
#  'Argentina,2010,485,14.98',
#  'Argentina,2010,397,14.49',
#  'Argentina,2010,573,12.33',
#  'Argentina,2010,150,4.47',
#  'Argentina,2010,162,3.37',
#  'Argentina,2010,101,3.15',
#  'Argentina,2010,99,3.08',
#  'Argentina,2010,34,2.75',
#  'Argentina,2010,33,0.92',
#  'Argentina,2010,20,0.58',
#  'Argentina,2011,178,26.38',
#  'Argentina,2011,693,19.96',
#  'Argentina,2011,510,15.65',
#  'Argentina,2011,416,14.92',
#  'Argentina,2011,504,10.64',
#  'Argentina,2011,172,5.1',
#  'Argentina,2011,157,3.21',
#  'Argentina,2011,102,3.16',
#  'Argentina,2011,93,2.85',
#  'Argentina,2011,30,2.38',
#  'Argentina,2011,29,0.84',
#  'Argentina,2011,28,0.78',
#  'Argentina,2012,225,32.68',
#  'Argentina,2012,745,21.4',
#  'Argentina,2012,616,18.85',
#  'Argentina,2012,451,15.88',
#  'Argentina,2012,554,11.44',
#  'Argentina,2012,204,6.03',
#  'Argentina,2012,164,3.28',
#  'Argentina,2012,108,3.24',
#  'Argentina,2012,102,3.16',
#  'Argentina,2012,33,2.57',
#  'Argentina,2012,29,0.8',
#  'Argentina,2012,17,0.49',
#  'Argentina,2013,168,24.03',
#  'Argentina,2013,696,19.96',
#  'Argentina,2013,499,15.25',
#  'Argentina,2013,398,13.75',
#  'Argentina,2013,604,12.2',
#  'Argentina,2013,167,4.93',
#  'Argentina,2013,102,3.16',
#  'Argentina,2013,157,3.08',
#  'Argentina,2013,102,3.01',
#  'Argentina,2013,29,2.23',
#  'Argentina,2013,32,0.91',
#  'Argentina,2013,33,0.91',
#  'Argentina,2014,192,27.16',
#  'Argentina,2014,738,21.13',
#  'Argentina,2014,531,16.2',
#  'Argentina,2014,405,13.72',
#  'Argentina,2014,644,12.73',
#  'Argentina,2014,204,6.02',
#  'Argentina,2014,196,3.77',
#  'Argentina,2014,118,3.66',
#  'Argentina,2014,109,3.15',
#  'Argentina,2014,25,1.89',
#  'Argentina,2014,35,0.99',
#  'Argentina,2014,34,0.93',
#  'Argentina,2015,245,34.38',
#  'Argentina,2015,656,18.74',
#  'Argentina,2015,431,14.31',
#  'Argentina,2015,465,14.13',
#  'Argentina,2015,633,12.25',
#  'Argentina,2015,153,4.51',
#  'Argentina,2015,125,3.55',
#  'Argentina,2015,114,3.52',
#  'Argentina,2015,166,3.13',
#  'Argentina,2015,27,2.01',
#  'Argentina,2015,39,1.06',
#  'Argentina,2015,19,0.54',
#  'Armenia,1990,25,7.51',
#  'Armenia,1990,2,7.43',
#  'Armenia,1990,11,5.98',
#  'Armenia,1990,16,5.21',
#  'Armenia,1990,15,4.19',
#  'Armenia,1990,10,3.67',
#  'Armenia,1990,6,2.68',
#  'Armenia,1990,1,2.04',
#  'Armenia,1990,4,1.25',
#  'Armenia,1990,3,1.16',
#  'Armenia,1990,0,0.0',
#  'Armenia,1990,0,0.0',
#  'Armenia,1991,5,17.36',
#  'Armenia,1991,20,6.37',
#  'Armenia,1991,11,4.44',
#  'Armenia,1991,9,4.43',
#  'Armenia,1991,14,4.02',
#  'Armenia,1991,2,3.78',
#  'Armenia,1991,9,2.27',
#  'Armenia,1991,6,2.03',
#  'Armenia,1991,4,1.17',
#  'Armenia,1991,0,0.0',
#  'Armenia,1991,0,0.0',
#  'Armenia,1991,0,0.0',
#  'Armenia,1992,3,10.64',
#  'Armenia,1992,15,6.97',
#  'Armenia,1992,22,6.1',
#  'Armenia,1992,15,4.8',
#  'Armenia,1992,10,3.8',
#  'Armenia,1992,2,3.75',
#  'Armenia,1992,9,3.0',
#  'Armenia,1992,6,1.46',
#  'Armenia,1992,1,0.34',
#  'Armenia,1992,0,0.0',
#  'Armenia,1992,0,0.0',
#  'Armenia,1992,0,0.0',
#  'Armenia,1993,6,11.3',
#  'Armenia,1993,20,8.83',
#  'Armenia,1993,2,7.04',
#  'Armenia,1993,25,6.72',
#  ...]

# %% [markdown]
# # **Ejemplo de Hive**
#
#
# Utilizando Hive para crear y leer una tabla

# %%
from pyspark.sql import Row
from pyspark.sql import HiveContext
sqlContext = HiveContext(sc)
test_list = [('A', 25),('B', 20),('C', 25),('D', 18)]
rdd = sc.parallelize(test_list)
people = rdd.map(lambda x: Row(name=x[0], age=int(x[1])))
schemaPeople = sqlContext.createDataFrame(people)
# Register it as a temp table
sqlContext.registerDataFrameAsTable(schemaPeople, "test_table")
sqlContext.sql("show tables").show()
# Out:
# /content/spark-4.1.1-bin-hadoop3/python/pyspark/sql/context.py:731: FutureWarning: HiveContext is deprecated in Spark 2.0.0. Please use SparkSession.builder.enableHiveSupport().getOrCreate() instead.
#   warnings.warn(
# /content/spark-4.1.1-bin-hadoop3/python/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# +---------+----------+-----------+
# |namespace| tableName|isTemporary|
# +---------+----------+-----------+
# |         |test_table|       true|
# +---------+----------+-----------+

# %% [markdown]
# Realizamos la consulta

# %%
sqlContext.sql("Select * from test_table").show()
# Out:
# +----+---+
# |name|age|
# +----+---+
# |   A| 25|
# |   B| 20|
# |   C| 25|
# |   D| 18|
# +----+---+

# %% [markdown]
# **Cargar el JSON en Hive y consultarlo**

# %% [markdown]
# Carguemos Example1.json con Hive y hagamos una sentencia Select en él

# %%
from pyspark.sql import HiveContext
hiveCtx = HiveContext(sc)
ex1 = hiveCtx.read.option("multiline","true").json("Example1.json")
ex1.registerTempTable("ex1")
results = hiveCtx.sql("SELECT event_name, init_date FROM ex1").show()
# Out:
# /content/spark-4.1.1-bin-hadoop3/python/pyspark/sql/classic/dataframe.py:178: FutureWarning: Deprecated in 2.0, use createOrReplaceTempView instead.
#   warnings.warn("Deprecated in 2.0, use createOrReplaceTempView instead.", FutureWarning)
# +--------------------+---------+
# |          event_name|init_date|
# +--------------------+---------+
# |       CosmosDB Conf| 20180613|
# |    Vue.js Conf 2018| 20180501|
# |           IoT Space| 20180621|
# |       CosmosDB Conf| 20180613|
# |Cloud Conference ...| 20180411|
# +--------------------+---------+
